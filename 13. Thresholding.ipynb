# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# THresholding is binarization of a image

# %%
img = cv2.imread('G:/New folder/animal.jpg')
cv2.imshow('Animal', img)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray', gray)
cv2.waitKey(0)
plt.imshow(img)

# %% [markdown]
# # Simple thresholding

# %%
threshold, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
cv2.imshow('Simple Thresholded', thresh)

cv2.waitKey(0)
plt.imshow(thresh)

# %% [markdown]
# # Inverse threshold

# %%
threshold, thresh_inv = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)
cv2.imshow('Simple Thresholded Inverse', thresh_inv)

cv2.waitKey(0)
plt.imshow(thresh_inv)

# %% [markdown]
# # Adaptive thresholding

# %%
# adaptiveThreshold(src, maxValue, adaptiveMethod, thresholdType, blockSize, C[, dst])
#     blockSize ---> neghiborhood size of kernel size
#     c value ----> it is the integer value that is subtracted from mean----more the the value--> more dark
adaptive_thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 3)
cv2.imshow('Adaptive Thresholding ', adaptive_thresh)
cv2.waitKey(0)
plt.imshow(adaptive_thresh)

# %%
adaptive_thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 3)   #inv
cv2.imshow('Adaptive Thresholding ', adaptive_thresh)
cv2.waitKey(0)
plt.imshow(adaptive_thresh)

# %%
# ADAPTIVE_THRESH_GAUSSIAN_C
adaptive_thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 3)   #inv
cv2.imshow('Adaptive Thresholding ', adaptive_thresh)
cv2.waitKey(0)
plt.imshow(adaptive_thresh)
